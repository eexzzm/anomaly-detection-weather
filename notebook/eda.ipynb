# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# https://www.kaggle.com/datasets/mnassrib/jena-climate

# %%
df = pd.read_csv("../data/raw/jena_climate_2009_2016.csv")

# %% [markdown]
# ## a

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420551 entries, 0 to 420550
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date Time        420551 non-null  object
#  1   p (mbar)         420551 non-null  float64
#  2   T (degC)         420551 non-null  float64
#  3   Tpot (K)         420551 non-null  float64
#  4   Tdew (degC)      420551 non-null  float64
#  5   rh (%)           420551 non-null  float64
#  6   VPmax (mbar)     420551 non-null  float64
#  7   VPact (mbar)     420551 non-null  float64
#  8   VPdef (mbar)     420551 non-null  float64
#  9   sh (g/kg)        420551 non-null  float64
#  10  H2OC (mmol/mol)  420551 non-null  float64
#  11  rho (g/m**3)     420551 non-null  float64
#  12  wv (m/s)         420551 non-null  float64
#  13  max. wv (m/s)    420551 non-null  float64
#  14  wd (deg)         420551 non-null  float64
# dtypes: float64(14), object(1)
# ...

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
df.describe()
# Out:
#                            Date Time       p (mbar)       T (degC)  \
# count                         420551  420551.000000  420551.000000
# mean   2012-12-30 06:26:51.498725120     989.212776       9.450147
# min              2009-01-01 00:10:00     913.600000     -23.010000
# 25%              2010-12-31 03:25:00     984.200000       3.360000
# 50%              2012-12-30 06:20:00     989.580000       9.420000
# 75%              2014-12-29 18:55:00     994.720000      15.470000
# max              2017-01-01 00:00:00    1015.350000      37.280000
# std                              NaN       8.358481       8.423365
#
#             Tpot (K)    Tdew (degC)         rh (%)   VPmax (mbar)  \
# count  420551.000000  420551.000000  420551.000000  420551.000000
# mean      283.492743       4.955854      76.008259      13.576251
# min       250.600000     -25.010000      12.950000       0.950000
# 25%       277.430000       0.240000      65.210000       7.780000
# ...

# %% [markdown]
# both wv (m/s) and max. wv (m/s) column contain error values (-9999)

# %%
print(f'number of columns contain error value: {len(df[df["wv (m/s)"] < 0])}')
df[df["wv (m/s)"] < 0].head()
# Out:
# number of columns contain error value: 18
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 343578  13.07.2015 09:10:00    990.49     16.85    290.80        12.78
# 343579  13.07.2015 09:20:00    990.32     17.06    291.03        12.86
# 343580  13.07.2015 09:30:00    990.24     17.43    291.41        12.75
# 343581  13.07.2015 09:40:00    990.27     17.71    291.68        12.88
# 343582  13.07.2015 09:50:00    990.28     17.76    291.73        13.03
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 343578    76.9         19.22         14.78          4.44       9.34
# 343579    76.3         19.48         14.86          4.62       9.39
# 343580    74.0         19.94         14.76          5.19       9.32
# 343581    73.3         20.30         14.88          5.42       9.40
# 343582    73.8         20.36         15.03          5.33       9.49
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
print(f'number of columns contain error value: {len(df[df["max. wv (m/s)"] < 0])}')
df[df["max. wv (m/s)"] < 0].head()
# Out:
# number of columns contain error value: 20
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 343577  13.07.2015 09:00:00    990.52     16.98    290.93        12.94
# 343578  13.07.2015 09:10:00    990.49     16.85    290.80        12.78
# 343579  13.07.2015 09:20:00    990.32     17.06    291.03        12.86
# 343580  13.07.2015 09:30:00    990.24     17.43    291.41        12.75
# 343581  13.07.2015 09:40:00    990.27     17.71    291.68        12.88
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 343577    77.1         19.38         14.94          4.44       9.44
# 343578    76.9         19.22         14.78          4.44       9.34
# 343579    76.3         19.48         14.86          4.62       9.39
# 343580    74.0         19.94         14.76          5.19       9.32
# 343581    73.3         20.30         14.88          5.42       9.40
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
df["Date Time"] = pd.to_datetime(df["Date Time"], format='%d.%m.%Y %H:%M:%S')
# df.iloc[1728]

# %%
df.corr()
# Out:
#                  Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# Date Time         1.000000  0.101275  0.110030  0.101240     0.128238
# p (mbar)          0.101275  1.000000 -0.045375 -0.124718    -0.066755
# T (degC)          0.110030 -0.045375  1.000000  0.996827     0.895708
# Tpot (K)          0.101240 -0.124718  0.996827  1.000000     0.894911
# Tdew (degC)       0.128238 -0.066755  0.895708  0.894911     1.000000
# rh (%)           -0.011241 -0.018352 -0.572416 -0.567127    -0.156615
# VPmax (mbar)      0.086787 -0.031546  0.951113  0.947293     0.799271
# VPact (mbar)      0.108469 -0.054370  0.867673  0.866205     0.968344
# VPdef (mbar)      0.044477 -0.003401  0.761744  0.756962     0.435752
# sh (g/kg)         0.106553 -0.069762  0.866755  0.866533     0.967599
# H2OC (mmol/mol)   0.106658 -0.069804  0.867177  0.866955     0.968044
# rho (g/m**3)     -0.081860  0.307640 -0.963410 -0.981345    -0.885232
# ...
