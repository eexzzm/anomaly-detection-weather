# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc = {'figure.figsize':(12, 8)})

pd.set_option("display.max_column", None)

# %%
df = pd.read_parquet("../data/interim/features.parquet")

# %%
df.head(50)
# Out:
#                      p (mbar)  T (degC)  Tdew (degC)    rh (%)  VPact (mbar)  \
# Date Time
# 2009-01-01 00:10:00  0.659069 -1.440496    -1.434959  0.579470     -0.936482
# 2009-01-01 00:20:00  0.663818 -1.472727    -1.473577  0.583609     -0.951140
# 2009-01-01 00:30:00  0.660019 -1.480992    -1.476626  0.604305     -0.952769
# 2009-01-01 00:40:00  0.658120 -1.464463    -1.452236  0.616722     -0.942997
# 2009-01-01 00:50:00  0.658120 -1.461157    -1.449187  0.612583     -0.941368
# 2009-01-01 01:00:00  0.657170 -1.442975    -1.422764  0.625000     -0.931596
# 2009-01-01 01:10:00  0.657170 -1.407438    -1.373984  0.641556     -0.912052
# 2009-01-01 01:20:00  0.657170 -1.407438    -1.380081  0.625000     -0.913681
# 2009-01-01 01:30:00  0.657170 -1.431405    -1.417683  0.600166     -0.929967
# 2009-01-01 01:40:00  0.660019 -1.474380    -1.479675  0.571192     -0.954397
# 2009-01-01 01:50:00  0.668566 -1.501653    -1.512195  0.571192     -0.965798
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# p_mean_12h             747
# T_std_12h              747
# rh_mean_12h            747
# rh_std_12h             747
# T_mean_12h             747
# p_std_12h              747
# p_std_3h               585
# T_std_3h               585
# rh_mean_3h             585
# p_mean_3h              585
# T_mean_3h              585
# rh_std_3h              585
# dp_60                  552
# dT_60                  552
# drh_60                 552
# p_std_1h               549
# T_mean_1h              549
# rh_std_1h              549
# p_mean_1h              549
# rh_mean_1h             549
# T_std_1h               549
# wv (m/s)               544
# wd (deg)               544
# max. wv (m/s)          544
# dT_30                  543
# dp_30                  543
# drh_30                 543
# drh_10                 537
# dT_10                  537
# dp_10                  537
# VPdef (mbar)           534
# Tdew (degC)            534
# rh (%)                 534
# T (degC)               534
# ...

# %% [markdown]
# with the highest number of nan values is 747, it is harmless for our data with 420767 rows

# %%
df.describe().T.sort_values("max").tail(20)
# Out:
#                   count      mean       std         min       25%  \
# dew_spread     420233.0  0.240281  0.807518   -0.708861 -0.373418
# max. wv (m/s)  420223.0  0.192256  0.787225   -0.996633 -0.404040
# dT_60          420215.0  0.071469  1.038525  -11.102041 -0.479592
# rh_std_3h      420182.0  0.234953  0.853746   -0.782240 -0.383556
# T_std_3h       420182.0  0.247654  0.892134   -0.807199 -0.392047
# VPdef (mbar)   420233.0  0.419960  1.106616   -0.493213 -0.296380
# dT_30          420224.0  0.075515  1.115719  -17.528302 -0.471698
# drh_60         420215.0 -0.048492  1.115142  -11.513317 -0.515738
# wv (m/s)       420223.0  0.197847  0.825830   -0.941176 -0.411765
# dT_10          420230.0  0.050030  1.240537  -26.150000 -0.500000
# T_std_1h       420218.0  0.273426  0.969974   -0.781599 -0.386393
# rh_std_1h      420218.0  0.298201  1.046760   -0.759471 -0.373838
# drh_30         420224.0 -0.043542  1.218457  -17.765217 -0.521739
# ...

# %% [markdown]
# resampling do not create explosive and error values

# %%
df["p_std_3h"].plot(figsize=(15,4))
plt.show()

# %% [markdown]
# sudden spike to 120 from around 0-10

# %%
df[["dT_10", "dT_30", "dT_60"]].plot(figsize=(15,4))
plt.show()

# %% [markdown]
# dT does not cross +50, looks safe and reasonable

# %%
df.filter(like="_filled").sum().sort_values()
# Out:
# p (mbar)_filled        544
# T (degC)_filled        544
# Tdew (degC)_filled     544
# rh (%)_filled          544
# VPact (mbar)_filled    544
# VPdef (mbar)_filled    544
# dtype: int64

# %%
df.sample(5).T
# Out:
# Date Time           2009-11-08 23:30:00 2015-06-29 19:10:00  \
# p (mbar)                      -0.796771            0.317189
# T (degC)                      -0.450413            1.270248
# Tdew (degC)                   -0.224593            0.753049
# rh (%)                         0.587748           -1.347682
# VPact (mbar)                   -0.20684            0.941368
# VPdef (mbar)                  -0.373303            3.280543
# wv (m/s)                       1.352941           -0.449198
# max. wv (m/s)                  1.107744           -0.511785
# wd (deg)                      -1.570788            0.514652
# dT_10                               0.1               -0.65
# dT_30                         -0.056604           -0.509434
# dT_60                         -0.142857            -1.22449
# dp_10                              -0.5            0.083333
# dp_30                         -0.071429            0.428571
# dp_60                         -0.192308            0.403846
# ...

# %%
sns.heatmap(df.corr(), cmap="coolwarm", center=0)
# Out:
# <Axes: >

# %%
df
# Out:
#                      p (mbar)  T (degC)  Tdew (degC)    rh (%)  VPact (mbar)  \
# Date Time
# 2009-01-01 00:10:00  0.659069 -1.440496    -1.434959  0.579470     -0.936482
# 2009-01-01 00:20:00  0.663818 -1.472727    -1.473577  0.583609     -0.951140
# 2009-01-01 00:30:00  0.660019 -1.480992    -1.476626  0.604305     -0.952769
# 2009-01-01 00:40:00  0.658120 -1.464463    -1.452236  0.616722     -0.942997
# 2009-01-01 00:50:00  0.658120 -1.461157    -1.449187  0.612583     -0.941368
# ...                       ...       ...          ...       ...           ...
# 2016-12-31 23:10:00  1.000000 -1.102479    -1.352642 -0.277318     -0.903909
# 2016-12-31 23:20:00  0.996201 -1.112397    -1.356707 -0.256623     -0.905537
# 2016-12-31 23:30:00  0.982906 -1.054545    -1.349593 -0.396937     -0.902280
# 2016-12-31 23:40:00  0.972460 -1.038843    -1.364837 -0.471440     -0.908795
# 2016-12-31 23:50:00  0.971510 -1.127273    -1.397358 -0.310430     -0.921824
#
# ...
